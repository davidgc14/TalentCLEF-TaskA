# %% [markdown]
# # Graficas de evaluacion final

# %%
import pandas as pd

df = pd.read_csv('models/results/evaluation_results.csv')
df
# Out:
#                                             model_name  num_params  \
# 0                 Lajavaness/bilingual-embedding-large   559890432
# 1             chienpham/sts-multilingual-mpnet-base-v2   278043648
# 2    AIDA-UPM/mstsb-paraphrase-multilingual-mpnet-b...   278043648
# 3                          shtilev/medical_embedded_v4   278043648
# 4    sentence-transformers/paraphrase-multilingual-...   278043648
# ..                                                 ...         ...
# 179    dccuchile/albert-base-spanish-distilled-qa-sqac    11811584
# 180     dccuchile/albert-base-10-spanish-distilled-ner    11811584
# 181  dccuchile/albert-base-10-spanish-distilled-qa-tar    11811584
# 182        dccuchile/albert-base-spanish-distilled-ner    11811584
# 183                     dccuchile/albert-large-spanish    17811968
#
#         languages  map_es_es       mrr      ndcg       p@5      p@10  \
# 0       bilingual   0.449344  0.546847  0.744623  0.650811  0.637838
# 1    multilingual   0.443588  0.551532  0.734145  0.654054  0.636757
# 2    multilingual   0.428735  0.547207  0.726293  0.640000  0.631892
# 3    multilingual   0.426456  0.545946  0.722666  0.647568  0.626486
# 4    multilingual   0.416908  0.551892  0.719501  0.640000  0.602162
# ..            ...        ...       ...       ...       ...       ...
# 179   monolingual   0.066581  0.386718  0.439594  0.250811  0.200541
# 180   monolingual   0.063189  0.396291  0.443869  0.237838  0.179459
# 181   monolingual   0.062703  0.395395  0.431764  0.242162  0.179459
# 182   monolingual   0.054585  0.340839  0.425897  0.191351  0.150811
# 183   monolingual   0.039061  0.338988  0.394872  0.184865  0.122703
#
#         p@100        source
# 0    0.244865          mteb
# 1    0.236757          mteb
# 2    0.231135          mteb
# 3    0.230919  hugging_face
# 4    0.226000  hugging_face
# ..        ...           ...
# 179  0.053622       spanish
# 180  0.055946       spanish
# 181  0.048324       spanish
# 182  0.051027       spanish
# 183  0.034324       spanish
#
# [184 rows x 10 columns]

# %%
# hacer grafica de puntos donde el eje x sea num_params y el eje y sea map_es_es. Diferencia por colores la fuente (source)
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(df['num_params'], df['map_es_es'], c=df['source'].map({'hugging_face': 'blue', 'spanish': 'green', 'mteb': 'red'}), alpha=0.7)
plt.xlabel('Número de parámetros')
plt.ylabel('MAP (es-es)')
plt.xscale('log')  # Escala logarítmica para el eje x
plt.grid(True)
# mostrar Leyenda 
handles = [plt.Line2D([0], [0], marker='o', color='w', label='Hugging Face', markerfacecolor='blue', markersize=10),
           plt.Line2D([0], [0], marker='o', color='w', label='Spanish', markerfacecolor='green', markersize=10),
           plt.Line2D([0], [0], marker='o', color='w', label='MTEB', markerfacecolor='red', markersize=10)]
plt.legend(handles=handles)
plt.show()

# %%
# ahora que se pinten en distintos colores los monolinuges y los multilingues
plt.figure(figsize=(10, 6))
plt.scatter(df['num_params'], df['map_es_es'], c=df['languages'].map({'monolingual': 'orange', 'multilingual': 'purple', 'bilingual': 'green'}), alpha=0.7)
plt.xlabel('Número de parámetros')
plt.ylabel('MAP (es-es)')
plt.xscale('log')  # Escala logarítmica para el eje x
plt.grid(True)
# mostrar Leyenda
handles = [plt.Line2D([0], [0], marker='o', color='w', label='Monolingual', markerfacecolor='orange', markersize=10),
           plt.Line2D([0], [0], marker='o', color='w', label='Multilingual', markerfacecolor='purple', markersize=10)]
plt.legend(handles=handles)
plt.show()
