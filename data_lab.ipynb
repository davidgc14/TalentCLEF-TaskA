# %%
import pandas as pd

# %% [markdown]
# # resultados de todos los modelos

# %%
df = pd.read_csv('models/results/hf_evaluation_results.csv')
df
# Out:
#                                            model_name  num_params  \
# 0                         shtilev/medical_embedded_v4   278043648
# 1   sentence-transformers/paraphrase-multilingual-...   278043648
# 2                   Alibaba-NLP/gte-multilingual-base   305368320
# 3                         shtilev/medical_embedded_v5   278043648
# 4                              upskyy/e5-large-korean   559890432
# 5                              upskyy/gte-base-korean   305368320
# 6                               upskyy/e5-base-korean   278043648
# 7     ibm-granite/granite-embedding-278m-multilingual   278043648
# 8                  OneFly7/biencoder_ep10_bs64_trans1   278043648
# 9                         shtilev/medical_embedded_v3   278043648
# 10  OneFly7/bi_bs32_lr2e5_cosine_restart_period2_best   278043648
# 11  sentence-transformers/paraphrase-multilingual-...   117653760
# 12     tomaarsen/distiluse-base-multilingual-cased-v2   134734080
# 13                  OneFly7/biencoder_ep2_bs32_trans3   278043648
# 14                               upskyy/bge-m3-korean   567754752
# 15     lang-uk/ukr-paraphrase-multilingual-mpnet-base   278043648
# 16                 Griffin88/sentence-embedding-LaBSE   471517440
# 17  OneFly7/biencoder_ep10_bs32_lr2e5_cosine_annea...   278043648
# 18                 OneFly7/biencoder_ep10_bs64_trans3   278043648
# 19            hiiamsid/sentence_similarity_spanish_es   109850880
# 20                    OneFly7/biencoder_ep10_bs64_all   278043648
# 21      DmitryML/distiluse-base-multilingual-cased-v1   135127808
# 22                             upskyy/e5-small-korean   117653760
# 23  emersoftware/tulio-chilean-spanish-bert-finetu...   109850880
# 24  OneFly7/biencoder_ep10_bs32_lr2e5_cosine_annea...   278043648
# 25  mrm8488/distiluse-base-multilingual-cased-v2-f...   134734080
# 26    symanto/sn-xlm-roberta-base-snli-mnli-anli-xnli   278043648
# 27  h4g3n/multilingual-MiniLM-L12-de-en-es-fr-it-n...   103458048
# 28              narraticlabs/MiniLM-L6-european-union   107006976
# 29  Maite89/Roberta_finetuning_semantic_similarity...   355356672
# 30                 OneFly7/biencoder_ep10_bs32_trans3   278043648
# 31  somosnlp-hackathon-2022/paraphrase-spanish-dis...   124645632
# 32  chukbert/paraphrase-multilingual-MiniLM-L12-v2...   117653760
# 33              LinerAI/Qwen3-Embedding-0.6B-academic   595776512
# 34       jaimevera1107/all-MiniLM-L6-v2-similarity-es    22713216
# 35                               facebook/drama-large   399803392
# 36                                  facebook/drama-1b  1235814400
# 37                                         clips/mfaq   278045952
# 38               OneFly7/crossencoder_ep10_bs8_trans1   278043648
# 39                                facebook/drama-base   211766016
# 40                        0xnu/pmmlv2-fine-tuned-igbo   117653760
# 41                       0xnu/pmmlv2-fine-tuned-hausa   117653760
# 42                      0xnu/pmmlv2-fine-tuned-yoruba   117653760
# 43                     0xnu/pmmlv2-fine-tuned-flemish   117653760
# 44                  j0h4nnes/decoy-ify_llama3.1_8B_v2   117653760
#
#        languages  map_es_es       mrr      ndcg       p@5      p@10     p@100
# 0   multilingual   0.426456  0.545946  0.722666  0.647568  0.626486  0.230919
# 1   multilingual   0.416908  0.551892  0.719501  0.640000  0.602162  0.226000
# 2   multilingual   0.415536  0.541441  0.722481  0.627027  0.614595  0.226054
# 44  multilingual   0.094253  0.427073  0.468344  0.339459  0.278919  0.072973

# %%
df.query('languages == "monolingual"')
# Out:
#                                            model_name  num_params  \
# 19            hiiamsid/sentence_similarity_spanish_es   109850880
# 23  emersoftware/tulio-chilean-spanish-bert-finetu...   109850880
# 29  Maite89/Roberta_finetuning_semantic_similarity...   355356672
# 31  somosnlp-hackathon-2022/paraphrase-spanish-dis...   124645632
# 34       jaimevera1107/all-MiniLM-L6-v2-similarity-es    22713216
#
#       languages  map_es_es       mrr      ndcg       p@5      p@10     p@100
# 19  monolingual   0.360081  0.538239  0.696669  0.616216  0.571351  0.209568
# 23  monolingual   0.347058  0.542122  0.684869  0.600000  0.558378  0.202432
# 29  monolingual   0.318717  0.519766  0.669148  0.572973  0.536216  0.194054
# 31  monolingual   0.306394  0.501105  0.643751  0.520000  0.489730  0.193946
# 34  monolingual   0.297729  0.525109  0.636365  0.589189  0.551892  0.164486

# %% [markdown]
# # Ranking MTEB

# %%
mteb = pd.read_csv('models/mteb-leaderboard-openmodels-retrieval.csv', index_col=0)
mteb
# Out:
#                                  Model_Name  Memory Usage (MB)  \
# 0            nvidia/llama-embed-nemotron-8b            28629.0
# 1    tencent/KaLM-Embedding-Gemma3-12B-2511            44884.0
# 2                   Qwen/Qwen3-Embedding-8B            14433.0
# 3                   Qwen/Qwen3-Embedding-4B             7671.0
# 4                    infly/inf-retriever-v1            13483.0
# ..                                      ...                ...
# 143               cointegrated/rubert-tiny2               45.0
# 144            DeepPavlov/rubert-base-cased             4883.0
# 145           ai-forever/sbert_large_nlu_ru             1629.0
# 146        ai-forever/sbert_large_mt_nlu_ru             1629.0
# 147                binhquoc/deberta-v1-base              473.0
#
#      Number of Parameters  Rank (Borda)  Retrieval  \
# 0            7.000000e+09             1      68.69
# 1            1.100000e+10             2      75.66
# 2            7.000000e+09             3      70.88
# 3            4.000000e+09             4      69.60
# 4            7.000000e+09             5      66.48
# ..                    ...           ...        ...
# 143          1.100000e+07           144      12.09
# 144          1.000000e+09           145       7.97
# 145          4.270000e+08           146       7.80
# 146          4.270000e+08           147       8.47
# 147          1.240000e+08           148       6.63
#
#                                             Model_Link  \
# 0    https://huggingface.co/nvidia/llama-embed-nemo...
# 1                    https://kalm-embedding.github.io/
# 2       https://huggingface.co/Qwen/Qwen3-Embedding-8B
# 3       https://huggingface.co/Qwen/Qwen3-Embedding-4B
# 4        https://huggingface.co/infly/inf-retriever-v1
# ..                                                 ...
# 143    https://huggingface.co/cointegrated/rubert-tiny
# 144  https://huggingface.co/DeepPavlov/rubert-base-...
# 145  https://huggingface.co/ai-forever/sbert_large_...
# 146  https://huggingface.co/ai-forever/sbert_large_...
# 147      https://huggingface.co/deepvk/deberta-v1-base
#
#                          Short_Name
# 0           llama-embed-nemotron-8b
# 1    KaLM-Embedding-Gemma3-12B-2511
# 2                Qwen3-Embedding-8B
# 3                Qwen3-Embedding-4B
# 4                  inf-retriever-v1
# ..                              ...
# 143                     rubert-tiny
# 144               rubert-base-cased
# 145              sbert_large_nlu_ru
# 146           sbert_large_mt_nlu_ru
# 147                 deberta-v1-base
#
# [141 rows x 7 columns]

# %%
mteb.head(99).sort_values('Memory Usage (MB)', ascending=False)[['Model_Name', 'Memory Usage (MB)']].head(20)
# Out:
#                                            Model_Name  Memory Usage (MB)
# 15                                 GritLM/GritLM-8x7B            89079.0
# 1              tencent/KaLM-Embedding-Gemma3-12B-2511            44884.0
# 6                   Alibaba-NLP/gte-Qwen2-7B-instruct            29040.0
# 0                      nvidia/llama-embed-nemotron-8b            28629.0
# 50  McGill-NLP/LLM2Vec-Mistral-7B-Instruct-v2-mntp...            27126.0
# 18                                 nvidia/NV-Embed-v1            14975.0
# 10                                 nvidia/NV-Embed-v2            14975.0
# 2                             Qwen/Qwen3-Embedding-8B            14433.0
# 13                         parasail-ai/GritLM-7B-vllm            13813.0
# 7                 Linq-AI-Research/Linq-Embed-Mistral            13563.0
# 14                   Salesforce/SFR-Embedding-Mistral            13563.0
# 19                    intfloat/e5-mistral-7b-instruct            13563.0
# 16                       Salesforce/SFR-Embedding-2_R            13563.0
# 4                              infly/inf-retriever-v1            13483.0
# 3                             Qwen/Qwen3-Embedding-4B             7671.0
# 5                           jinaai/jina-embeddings-v4             7500.0
# 8                 Alibaba-NLP/gte-Qwen2-1.5B-instruct             6776.0
# 22                       NovaSearch/stella_en_1.5B_v5             5887.0
# 17            NovaSearch/jasper_en_vision_language_v1             3802.0
# 12                        infly/inf-retriever-v1-1.5b             2944.0

# %%
mteb_list = mteb.head(99).query('`Memory Usage (MB)` < 20000').sort_values('Memory Usage (MB)', ascending=False)[['Model_Name']].values.tolist()
mteb_list = [item for sublist in mteb_list for item in sublist]

mteb_list
# Out:
# ['nvidia/NV-Embed-v2',
#  'nvidia/NV-Embed-v1',
#  'Qwen/Qwen3-Embedding-8B',
#  'parasail-ai/GritLM-7B-vllm',
#  'Linq-AI-Research/Linq-Embed-Mistral',
#  'Salesforce/SFR-Embedding-Mistral',
#  'Salesforce/SFR-Embedding-2_R',
#  'intfloat/e5-mistral-7b-instruct',
#  'infly/inf-retriever-v1',
#  'Qwen/Qwen3-Embedding-4B',
#  'jinaai/jina-embeddings-v4',
#  'Alibaba-NLP/gte-Qwen2-1.5B-instruct',
#  'NovaSearch/stella_en_1.5B_v5',
#  'NovaSearch/jasper_en_vision_language_v1',
#  'infly/inf-retriever-v1-1.5b',
#  'manu/sentence_croissant_alpha_v0.2',
#  'manu/sentence_croissant_alpha_v0.3',
#  'manu/sentence_croissant_alpha_v0.4',
#  'BAAI/bge-m3',
#  'Snowflake/snowflake-arctic-embed-l-v2.0',
#  'gandolfi/bge-m3-custom-fr-Q4_K_M-GGUF',
#  'OrdalieTech/Solon-embeddings-large-0.1',
#  'intfloat/multilingual-e5-large',
#  'sdadas/mmlw-e5-large',
#  'Lajavaness/bilingual-embedding-large',
#  'HIT-TMG/KaLM-embedding-multilingual-mini-instruct-v1',
#  'HIT-TMG/KaLM-embedding-multilingual-mini-v1',
#  'Omartificial-Intelligence-Space/Arabic-labse-Matryoshka',
#  'NovaSearch/stella_en_400M_v5',
#  'sdadas/mmlw-roberta-large',
#  'deepvk/USER-bge-m3',
#  'intfloat/multilingual-e5-large',
#  'avsolatorio/GIST-large-Embedding-v0',
#  'intfloat/e5-large-v2',
#  'WhereIsAI/UAE-Large-V1',
#  'Snowflake/snowflake-arctic-embed-l-v2.0',
#  'BAAI/bge-large-en-v1.5',
#  'Snowflake/snowflake-arctic-embed-m-v2.0',
#  'google/embeddinggemma-300m',
#  'Qwen/Qwen3-Embedding-0.6B',
#  'jinaai/jina-embeddings-v3',
#  'intfloat/multilingual-e5-large-instruct',
#  'Lajavaness/bilingual-embedding-base',
#  'Omartificial-Intelligence-Space/Arabic-all-nli-triplet-Matryoshka',
#  'AIDA-UPM/mstsb-paraphrase-multilingual-mpnet-base-v2',
#  'chienpham/sts-multilingual-mpnet-base-v2',
#  'intfloat/multilingual-e5-base',
#  'sdadas/mmlw-e5-base',
#  'mixedbread-ai/mxbai-embed-large-v1',
#  'thenlper/gte-large',
#  'Alibaba-NLP/gte-multilingual-base',
#  'ibm-granite/granite-embedding-278m-multilingual',
#  'Snowflake/snowflake-arctic-embed-m-long',
#  'nomic-ai/nomic-embed-text-v1.5',
#  'nomic-ai/nomic-embed-text-v1.5',
#  'minishlab/potion-multilingual-128M',
#  'intfloat/multilingual-e5-small',
#  'Lajavaness/bilingual-embedding-small',
#  'sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2',
#  'Omartificial-Intelligence-Space/Arabic-MiniLM-L12-v2-all-nli-triplet',
#  'jinaai/jina-embedding-b-en-v1',
#  'intfloat/multilingual-e5-base',
#  'sentence-transformers/all-mpnet-base-v2',
#  'intfloat/e5-base-v2',
#  'avsolatorio/GIST-Embedding-v0',
#  'Snowflake/snowflake-arctic-embed-m-v1.5',
#  'Snowflake/snowflake-arctic-embed-m-v1.5',
#  'sentence-transformers/static-similarity-mrl-multilingual-v1',
#  nan,
#  'BAAI/bge-base-en-v1.5',
#  'ibm-granite/granite-embedding-125m-english',
#  'thenlper/gte-base',
#  'bartowski/granite-embedding-107m-multilingual-GGUF',
#  'jinaai/jina-embedding-s-en-v1',
#  'BAAI/bge-small-en-v1.5',
#  'avsolatorio/GIST-small-Embedding-v0',
#  'intfloat/e5-small-v2',
#  'Snowflake/snowflake-arctic-embed-s',
#  'avsolatorio/NoInstruct-small-Embedding-v0',
#  'abhinand/MedEmbed-small-v0.1',
#  'intfloat/multilingual-e5-small',
#  'sentence-transformers/all-MiniLM-L12-v2',
#  'sentence-transformers/all-MiniLM-L6-v2',
#  'avsolatorio/GIST-all-MiniLM-L6-v2',
#  'brahmairesearch/slx-v0.1',
#  'Mihaiii/Ivysaur',
#  'Snowflake/snowflake-arctic-embed-l-v2.0',
#  'thenlper/gte-small',
#  'ibm-granite/granite-embedding-30m-english']

# %%
# exportar lista a txt
with open('mteb_models.txt', 'w') as f:
    for item in mteb_list:
        f.write("%s\n" % item)

# %% [markdown]
# # Spanish models

# %%
from huggingface_hub import list_models

# Lista de autores
autores = ["PlanTL-GOB-ES", "dccuchile"]
librerias = ["transformers", "sentence-transformers"]

# Recopilar modelos de todos los autores
todos_los_modelos = []

for libreria in librerias:
    for autor in autores:
        modelos = list(list_models(
            author=autor,
            library=libreria,
        ))
        todos_los_modelos.extend(modelos)

# Ordenar por ID
todos_los_modelos = sorted(todos_los_modelos, key=lambda x: x.id)

# Mostrar los modelos
print(f"Total de modelos encontrados: {len(todos_los_modelos)}\n")
for model in todos_los_modelos:
    print(model.id)
# Out:
# /home/david/Documents/Master/TFM/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in 'list_models': library. Will not be supported from version '1.0'.
#
# Use `filter` instead.
#   warnings.warn(message, FutureWarning)
# Total de modelos encontrados: 210
#
# PlanTL-GOB-ES/Controversy-Prediction
# PlanTL-GOB-ES/RoBERTalex
# PlanTL-GOB-ES/bsc-bio-ehr-es
# PlanTL-GOB-ES/bsc-bio-ehr-es-cantemist
# PlanTL-GOB-ES/bsc-bio-ehr-es-pharmaconer
# PlanTL-GOB-ES/bsc-bio-es
# PlanTL-GOB-ES/longformer-base-4096-biomedical-clinical-es
# PlanTL-GOB-ES/roberta-base-biomedical-clinical-es
# PlanTL-GOB-ES/roberta-base-biomedical-es
# PlanTL-GOB-ES/roberta-base-ca
# PlanTL-GOB-ES/roberta-base-es-wikicat-es
# dccuchile/albert-base-10-spanish
# dccuchile/albert-base-10-spanish-distilled-mldoc
# dccuchile/albert-base-10-spanish-distilled-ner
# dccuchile/albert-base-10-spanish-distilled-pawsx
# dccuchile/albert-base-10-spanish-distilled-pos
# dccuchile/albert-base-10-spanish-distilled-qa-mlqa
# dccuchile/albert-base-10-spanish-distilled-qa-sqac
# dccuchile/albert-base-10-spanish-distilled-qa-tar
# dccuchile/albert-base-10-spanish-distilled-xnli
# dccuchile/albert-base-10-spanish-finetuned-mldoc
# dccuchile/albert-base-10-spanish-finetuned-ner
# dccuchile/albert-base-10-spanish-finetuned-pawsx
# dccuchile/albert-base-10-spanish-finetuned-pos
# dccuchile/albert-base-10-spanish-finetuned-qa-mlqa
# dccuchile/albert-base-10-spanish-finetuned-qa-sqac
# dccuchile/albert-base-10-spanish-finetuned-qa-tar
# dccuchile/albert-base-10-spanish-finetuned-xnli
# dccuchile/albert-base-2-spanish
# dccuchile/albert-base-2-spanish-distilled-mldoc
# dccuchile/albert-base-2-spanish-distilled-ner
# dccuchile/albert-base-2-spanish-distilled-pawsx
# dccuchile/albert-base-2-spanish-distilled-pos
# dccuchile/albert-base-2-spanish-distilled-qa-mlqa
# dccuchile/albert-base-2-spanish-distilled-qa-sqac
# dccuchile/albert-base-2-spanish-distilled-qa-tar
# dccuchile/albert-base-2-spanish-distilled-xnli
# dccuchile/albert-base-2-spanish-finetuned-mldoc
# dccuchile/albert-base-2-spanish-finetuned-ner
# dccuchile/albert-base-2-spanish-finetuned-pawsx
# dccuchile/albert-base-2-spanish-finetuned-pos
# dccuchile/albert-base-2-spanish-finetuned-qa-mlqa
# dccuchile/albert-base-2-spanish-finetuned-qa-sqac
# dccuchile/albert-base-2-spanish-finetuned-qa-tar
# dccuchile/albert-base-2-spanish-finetuned-xnli
# dccuchile/albert-base-4-spanish
# dccuchile/albert-base-4-spanish-distilled-mldoc
# dccuchile/albert-base-4-spanish-distilled-ner
# dccuchile/albert-base-4-spanish-distilled-pawsx
# dccuchile/albert-base-4-spanish-distilled-pos
# dccuchile/albert-base-4-spanish-distilled-qa-mlqa
# dccuchile/albert-base-4-spanish-distilled-qa-sqac
# dccuchile/albert-base-4-spanish-distilled-qa-tar
# dccuchile/albert-base-4-spanish-distilled-xnli
# dccuchile/albert-base-4-spanish-finetuned-mldoc
# dccuchile/albert-base-4-spanish-finetuned-ner
# dccuchile/albert-base-4-spanish-finetuned-pawsx
# dccuchile/albert-base-4-spanish-finetuned-pos
# dccuchile/albert-base-4-spanish-finetuned-qa-mlqa
# dccuchile/albert-base
# dccuchile/bert-base-spanish-wwm-uncased-finetuned-qa-tar
# dccuchile/bert-base-spanish-wwm-uncased-finetuned-xnli
# dccuchile/bertin-roberta-base-spanish-finetuned-mldoc
# dccuchile/bertin-roberta-base-spanish-finetuned-ner
# dccuchile/bertin-roberta-base-spanish-finetuned-pawsx
# dccuchile/bertin-roberta-base-spanish-finetuned-pos
# dccuchile/bertin-roberta-base-spanish-finetuned-qa-mlqa
# dccuchile/bertin-roberta-base-spanish-finetuned-qa-sqac
# dccuchile/bertin-roberta-base-spanish-finetuned-qa-tar
# dccuchile/bertin-roberta-base-spanish-finetuned-xnli
# dccuchile/distilbert-base-spanish-uncased
# dccuchile/distilbert-base-spanish-uncased-finetuned-mldoc
# dccuchile/distilbert-base-spanish-uncased-finetuned-ner
# dccuchile/distilbert-base-spanish-uncased-finetuned-pawsx
# dccuchile/distilbert-base-spanish-uncased-finetuned-pos
# dccuchile/distilbert-base-spanish-uncased-finetuned-qa-mlqa
# dccuchile/distilbert-base-spanish-uncased-finetuned-qa-sqac
# dccuchile/distilbert-base-spanish-uncased-finetuned-qa-tar
# dccuchile/distilbert-base-spanish-uncased-finetuned-xnli
# dccuchile/patana-chilean-spanish-bert
# dccuchile/roberta-base-bne-finetuned-mldoc
# dccuchile/roberta-base-bne-finetuned-ner
# dccuchile/roberta-base-bne-finetuned-pawsx
# dccuchile/roberta-base-bne-finetuned-pos
# dccuchile/roberta-base-bne-finetuned-qa-mlqa
# dccuchile/roberta-base-bne-finetuned-qa-sqac
# dccuchile/roberta-base-bne-finetuned-qa-tar
# dccuchile/roberta-base-bne-finetuned-xnli
# dccuchile/roberta-large-bne-finetuned-mldoc
# dccuchile/roberta-large-bne-finetuned-ner
# dccuchile/roberta-large-bne-finetuned-pawsx
# dccuchile/roberta-large-bne-finetuned-pos
# dccuchile/roberta-large-bne-finetuned-qa-mlqa
# dccuchile/roberta-large-bne-finetuned-qa-sqac
# dccuchile/roberta-large-bne-finetuned-qa-tar
# dccuchile/roberta-large-bne-finetuned-xnli
# dccuchile/tulio-chilean-spanish-bert

# %%
model_list = [model.id for model in todos_los_modelos if 'finetuned' not in model.id]
model_list
# Out:
# ['PlanTL-GOB-ES/Controversy-Prediction',
#  'PlanTL-GOB-ES/RoBERTalex',
#  'PlanTL-GOB-ES/bsc-bio-ehr-es',
#  'PlanTL-GOB-ES/bsc-bio-ehr-es-cantemist',
#  'PlanTL-GOB-ES/bsc-bio-ehr-es-pharmaconer',
#  'PlanTL-GOB-ES/bsc-bio-es',
#  'PlanTL-GOB-ES/longformer-base-4096-biomedical-clinical-es',
#  'PlanTL-GOB-ES/roberta-base-biomedical-clinical-es',
#  'PlanTL-GOB-ES/roberta-base-biomedical-es',
#  'PlanTL-GOB-ES/roberta-base-ca',
#  'PlanTL-GOB-ES/roberta-base-es-wikicat-es',
#  'dccuchile/albert-base-10-spanish',
#  'dccuchile/albert-base-10-spanish-distilled-mldoc',
#  'dccuchile/albert-base-10-spanish-distilled-ner',
#  'dccuchile/albert-base-10-spanish-distilled-pawsx',
#  'dccuchile/albert-base-10-spanish-distilled-pos',
#  'dccuchile/albert-base-10-spanish-distilled-qa-mlqa',
#  'dccuchile/albert-base-10-spanish-distilled-qa-sqac',
#  'dccuchile/albert-base-10-spanish-distilled-qa-tar',
#  'dccuchile/albert-base-10-spanish-distilled-xnli',
#  'dccuchile/albert-base-2-spanish',
#  'dccuchile/albert-base-2-spanish-distilled-mldoc',
#  'dccuchile/albert-base-2-spanish-distilled-ner',
#  'dccuchile/albert-base-2-spanish-distilled-pawsx',
#  'dccuchile/albert-base-2-spanish-distilled-pos',
#  'dccuchile/albert-base-2-spanish-distilled-qa-mlqa',
#  'dccuchile/albert-base-2-spanish-distilled-qa-sqac',
#  'dccuchile/albert-base-2-spanish-distilled-qa-tar',
#  'dccuchile/albert-base-2-spanish-distilled-xnli',
#  'dccuchile/albert-base-4-spanish',
#  'dccuchile/albert-base-4-spanish-distilled-mldoc',
#  'dccuchile/albert-base-4-spanish-distilled-ner',
#  'dccuchile/albert-base-4-spanish-distilled-pawsx',
#  'dccuchile/albert-base-4-spanish-distilled-pos',
#  'dccuchile/albert-base-4-spanish-distilled-qa-mlqa',
#  'dccuchile/albert-base-4-spanish-distilled-qa-sqac',
#  'dccuchile/albert-base-4-spanish-distilled-qa-tar',
#  'dccuchile/albert-base-4-spanish-distilled-xnli',
#  'dccuchile/albert-base-6-spanish',
#  'dccuchile/albert-base-6-spanish-distilled-mldoc',
#  'dccuchile/albert-base-6-spanish-distilled-ner',
#  'dccuchile/albert-base-6-spanish-distilled-pawsx',
#  'dccuchile/albert-base-6-spanish-distilled-pos',
#  'dccuchile/albert-base-6-spanish-distilled-qa-mlqa',
#  'dccuchile/albert-base-6-spanish-distilled-qa-sqac',
#  'dccuchile/albert-base-6-spanish-distilled-qa-tar',
#  'dccuchile/albert-base-6-spanish-distilled-xnli',
#  'dccuchile/albert-base-8-spanish',
#  'dccuchile/albert-base-8-spanish-distilled-mldoc',
#  'dccuchile/albert-base-8-spanish-distilled-ner',
#  'dccuchile/albert-base-8-spanish-distilled-pawsx',
#  'dccuchile/albert-base-8-spanish-distilled-pos',
#  'dccuchile/albert-base-8-spanish-distilled-qa-mlqa',
#  'dccuchile/albert-base-8-spanish-distilled-qa-sqac',
#  'dccuchile/albert-base-8-spanish-distilled-qa-tar',
#  'dccuchile/albert-base-8-spanish-distilled-xnli',
#  'dccuchile/albert-base-spanish',
#  'dccuchile/albert-base-spanish-distilled-mldoc',
#  'dccuchile/albert-base-spanish-distilled-ner',
#  'dccuchile/albert-base-spanish-distilled-pawsx',
#  'dccuchile/albert-base-spanish-distilled-pos',
#  'dccuchile/albert-base-spanish-distilled-qa-mlqa',
#  'dccuchile/albert-base-spanish-distilled-qa-sqac',
#  'dccuchile/albert-base-spanish-distilled-qa-tar',
#  'dccuchile/albert-base-spanish-distilled-xnli',
#  'dccuchile/albert-large-spanish',
#  'dccuchile/albert-tiny-spanish',
#  'dccuchile/albert-tiny-spanish-distilled-mldoc',
#  'dccuchile/albert-tiny-spanish-distilled-ner',
#  'dccuchile/albert-tiny-spanish-distilled-pawsx',
#  'dccuchile/albert-tiny-spanish-distilled-pos',
#  'dccuchile/albert-tiny-spanish-distilled-qa-mlqa',
#  'dccuchile/albert-tiny-spanish-distilled-qa-sqac',
#  'dccuchile/albert-tiny-spanish-distilled-qa-tar',
#  'dccuchile/albert-tiny-spanish-distilled-xnli',
#  'dccuchile/albert-xlarge-spanish',
#  'dccuchile/albert-xxlarge-spanish',
#  'dccuchile/bert-base-spanish-wwm-cased',
#  'dccuchile/bert-base-spanish-wwm-uncased',
#  'dccuchile/distilbert-base-spanish-uncased',
#  'dccuchile/patana-chilean-spanish-bert',
#  'dccuchile/tulio-chilean-spanish-bert']

# %%
model_list.extend([
    "hiiamsid/sentence_similarity_spanish_es",
    "hackathon-pln-es/paraphrase-spanish-distilroberta",
    "jinaai/jina-embeddings-v2-base-es",
    "jaimevera1107/all-MiniLM-L6-v2-similarity-es",
    "jaimevera1107/roberta-similarity-es",
    "bertin-project/bertin-roberta-base-spanish",
    "jfarray/Model_dccuchile_bert-base-spanish-wwm-uncased_100_Epochs"
])

# %%
# exportar lista a txt
with open('es_models.txt', 'w') as f:
    for item in model_list:
        f.write("%s\n" % item)
